# %% [markdown]
# <a href="https://colab.research.google.com/github/Wahibasa/Modele-Profond-Fashion-MNIST-/blob/main/fashion__nouveau_data_prof_pris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from skimage.metrics import peak_signal_noise_ratio as psnr_score
from skimage.metrics import structural_similarity as ssim_score

# =====================================================
# 1. PRÉPARATION DES DONNÉES
# =====================================================
(x_train, _), (x_test, _) = fashion_mnist.load_data()

x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0
x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)

y_train = x_train
y_test = x_test

# =====================================================
# 2. CONFIGURATION DE L'AUGMENTATION DE DONNÉES ET DU BRUIT
# =====================================================
data_gen_args = dict(
    rotation_range=10,
    width_shift_range=0.1,
    fill_mode='nearest'
)

train_datagen = ImageDataGenerator(**data_gen_args)
val_datagen = ImageDataGenerator(**data_gen_args)

train_generator = train_datagen.flow(x_train, y_train, batch_size=128, shuffle=True)
val_generator = val_datagen.flow(x_test, y_test, batch_size=128, shuffle=False)

noise_factor = 0.2

def noisy_generator(image_data_generator):
    for batch_x, batch_y in image_data_generator:
        noise = noise_factor * np.random.normal(loc=0.0, scale=1.0, size=batch_x.shape)
        batch_x_noisy = np.clip(batch_x + noise, 0., 1.)
        yield (batch_x_noisy, batch_y)

train_noisy_generator = noisy_generator(train_generator)
val_noisy_generator = noisy_generator(val_generator)

# =====================================================
# 3. ARCHITECTURE AUTOENCODEUR CONVOLUTIONNEL
# =====================================================
# Fonction métrique SSIM pour Keras (suivi pendant fit)
def ssim_metric(y_true, y_pred):
    return tf.reduce_mean(tf.image.ssim(y_true, y_pred, max_val=1.0))

input_img = layers.Input(shape=(28, 28, 1), name='Input_Layer')

x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(input_img)
x = layers.MaxPooling2D((2, 2), padding='same')(x)
x = layers.Conv2D(16, (3, 3), activation='relu', padding='same')(x)
x = layers.MaxPooling2D((2, 2), padding='same')(x)
x = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
encoded = layers.MaxPooling2D((2, 2), padding='same', name='bottleneck_layer')(x)

x = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(encoded)
x = layers.UpSampling2D((2, 2))(x)
x = layers.Conv2D(16, (3, 3), activation='relu', padding='same')(x)
x = layers.UpSampling2D((2, 2))(x)
x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = layers.UpSampling2D((2, 2))(x)
x = layers.Cropping2D(cropping=((2, 2), (2, 2)))(x)
decoded = layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

autoencoder = models.Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss='mse', metrics=[ssim_metric])
autoencoder.summary()

# =====================================================
# 4. ENTRAÎNEMENT
# =====================================================
early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

steps_per_epoch_train = len(x_train) // 128
steps_per_epoch_val = len(x_test) // 128

history = autoencoder.fit(
    train_noisy_generator,
    steps_per_epoch=steps_per_epoch_train,
    epochs=20,
    validation_data=val_noisy_generator,
    validation_steps=steps_per_epoch_val,
    callbacks=[early_stop]
)

# =====================================================
# 5. AFFICHAGE DES COURBES D'APPRENTISSAGE
# =====================================================
plt.figure(figsize=(12, 5))
# Courbe Loss
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss (MSE)')
plt.plot(history.history['val_loss'], label='Val Loss (MSE)')
plt.title('Perte (MSE)')
plt.legend()

# Courbe SSIM
plt.subplot(1, 2, 2)
plt.plot(history.history['ssim_metric'], label='Train SSIM', color='green')
plt.plot(history.history['val_ssim_metric'], label='Val SSIM', color='red')
plt.title('Similarité Structurelle (SSIM)')
plt.legend()
plt.show()

# =====================================================
# 6. GRAD-CAM & VISUALISATION
# =====================================================
x_test_noisy_for_display = np.clip(x_test + noise_factor * np.random.normal(size=x_test.shape), 0., 1.)

def make_gradcam_heatmap(img_array, model, last_conv_layer_name):
    grad_model = tf.keras.models.Model([model.inputs], [model.get_layer(last_conv_layer_name).output, model.output])
    with tf.GradientTape() as tape:
        conv_outputs, predictions = grad_model(img_array)
        loss = tf.reduce_mean(predictions)
    grads = tape.gradient(loss, conv_outputs)
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))
    conv_outputs = conv_outputs[0]
    heatmap = tf.reduce_sum(conv_outputs * pooled_grads, axis=-1)
    heatmap = tf.maximum(heatmap, 0)
    heatmap /= tf.math.reduce_max(heatmap) + 1e-8
    return heatmap.numpy()

n = 5
decoded_imgs = autoencoder.predict(x_test_noisy_for_display[:n])
plt.figure(figsize=(15, 12))

for i in range(n):
    sample = x_test_noisy_for_display[i:i+1]
    heatmap = make_gradcam_heatmap(sample, autoencoder, "bottleneck_layer")
    heatmap_resized = tf.image.resize(heatmap[..., np.newaxis], (28, 28))
    heatmap_resized = np.squeeze(heatmap_resized.numpy())

    plt.subplot(4, n, i + 1); plt.imshow(x_test[i].reshape(28, 28), cmap="gray"); plt.axis("off"); plt.title("Original")
    plt.subplot(4, n, i + 1 + n); plt.imshow(x_test_noisy_for_display[i].reshape(28, 28), cmap="gray"); plt.axis("off"); plt.title("Noisy")
    plt.subplot(4, n, i + 1 + 2*n); plt.imshow(decoded_imgs[i].reshape(28, 28), cmap="gray"); plt.axis("off"); plt.title("Denoised")
    plt.subplot(4, n, i + 1 + 3*n); plt.imshow(x_test_noisy_for_display[i].reshape(28, 28), cmap="gray")
    plt.imshow(heatmap_resized, cmap="jet", alpha=0.5); plt.axis("off"); plt.title("Grad-CAM")

plt.tight_layout(); plt.show()

# =====================================================
# 7. RÉSUMÉ DES RÉSULTATS NUMÉRIQUES FINAUX
# =====================================================
print("\n" + "="*65)
print(f"{'RÉSUMÉ DES MÉTRIQUES SUR LE JEU DE TEST':^65}")
print("="*65)

# Prédiction sur 1000 images pour des métriques stables
test_samples = x_test[:1000]
test_noisy = np.clip(test_samples + noise_factor * np.random.normal(size=test_samples.shape), 0., 1.)
predictions = autoencoder.predict(test_noisy, verbose=0)

# Calcul des scores
avg_mse = np.mean(np.square(test_samples - predictions))
avg_psnr = np.mean([psnr_score(test_samples[i], predictions[i], data_range=1.0) for i in range(1000)])
avg_ssim = np.mean([ssim_score(test_samples[i], predictions[i], data_range=1.0, channel_axis=-1) for i in range(1000)])

print(f"{'Métrique':<40} | {'Valeur':<20}")
print("-" * 65)
print(f"{'MSE (Erreur Quadratique Moyenne ↓)':<40} | {avg_mse:.6f}")
print(f"{'PSNR (Rapport Signal sur Bruit ↑)':<40} | {avg_psnr:.2f} dB")
print(f"{'SSIM (Similarité Structurelle ↑)':<40} | {avg_ssim:.4f}")
print("="*65)
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Input_Layer (InputLayer)        │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 28, 28, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 14, 14, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 14, 14, 16)     │         4,624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 7, 7, 16)       │             0 │
# ...
